# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../DATA/4-hours Pepperstone/4-hours_EURUSD.csv")

# %%
def candle_information(df):
    # Candle color
    df["candle_way"] = -1
    df.loc[(df["open"] - df["close"]) < 0, "candle_way"] = 1

    # Filling percentage
    df["filling"] = np.abs(df["close"] - df["open"]) / np.abs(df["high"] - df["low"])

    # Amplitude
    df["amplitude"] = np.abs(df["close"] - df["open"]) / (df["open"] / 2 + df["close"] / 2) * 100

    return df

# %%
df = candle_information(df)
df
# Out:
#                       time     open     high      low    close  tick_volume  \
# 0      2015-01-02 12:00:00  1.20467  1.20600  1.20347  1.20377        14827
# 1      2015-01-02 16:00:00  1.20377  1.20437  1.20069  1.20131        19160
# 2      2015-01-02 20:00:00  1.20133  1.20154  1.20011  1.20029         9335
# 3      2015-01-03 00:00:00  1.20030  1.20055  1.19997  1.20014         1351
# 4      2015-01-05 00:00:00  1.19454  1.19755  1.18642  1.19624        13941
# ...                    ...      ...      ...      ...      ...          ...
# 13671  2023-09-19 16:00:00  1.06997  1.07014  1.06785  1.06848        13607
# 13672  2023-09-19 20:00:00  1.06848  1.06918  1.06761  1.06790         6544
# 13673  2023-09-20 00:00:00  1.06790  1.06860  1.06768  1.06849         2478
# 13674  2023-09-20 04:00:00  1.06849  1.06897  1.06783  1.06786         4333
# 13675  2023-09-20 08:00:00  1.06786  1.06972  1.06730  1.06964        11014
#
#                   low_time            high_time  candle_way   filling  \
# 0      2015-01-02 15:36:00  2015-01-02 12:48:00          -1  0.355731
# 1      2015-01-02 19:36:00  2015-01-02 16:00:00          -1  0.668478
# 2      2015-01-02 23:12:00  2015-01-02 20:00:00          -1  0.727273
# 3      2015-01-03 00:24:00  2015-01-03 00:00:00          -1  0.275862
# 4      2015-01-05 00:48:00  2015-01-05 03:36:00           1  0.152740
# ...                    ...                  ...         ...       ...
# 13671  2023-09-19 19:36:00  2023-09-19 16:00:00          -1  0.650655
# 13672  2023-09-19 22:00:00  2023-09-19 20:24:00          -1  0.369427
# 13673  2023-09-20 00:00:00  2023-09-20 03:36:00           1  0.641304
# 13674  2023-09-20 06:24:00  2023-09-20 05:12:00          -1  0.552632
# 13675  2023-09-20 08:48:00  2023-09-20 11:36:00           1  0.735537
#
#        amplitude
# 0       0.074737
# 1       0.204567
# 2       0.086608
# 3       0.013331
# 4       0.142213
# ...          ...
# 13671   0.139353
# 13672   0.054297
# 13673   0.055233
# 13674   0.058979
# 13675   0.166550
#
# [13676 rows x 11 columns]

# %%
df[["candle_way"]].plot()
# Out:
# <AxesSubplot:>
